# %% [markdown]
# # Music Recommendation using K-Means Clusering

# %%
#1.import libraries
import warnings
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm import tqdm
sns.set()

# %%
data = pd.read_csv("music.csv")
data.head(50)
# Out:
#     acousticness                              artists  danceability  \
# 0       0.991000                      ['Mamie Smith']         0.598
# 1       0.643000            ["Screamin' Jay Hawkins"]         0.852
# 2       0.993000                      ['Mamie Smith']         0.647
# 3       0.000173                  ['Oscar Velazquez']         0.730
# 4       0.295000                             ['Mixe']         0.704
# 5       0.996000    ['Mamie Smith & Her Jazz Hounds']         0.424
# 6       0.992000                      ['Mamie Smith']         0.782
# 7       0.996000    ['Mamie Smith & Her Jazz Hounds']         0.474
# 8       0.996000                 ['Francisco Canaro']         0.469
# 9       0.006820                           ['Meetya']         0.571
# 10      0.952000                         ['Dorville']         0.688
# 11      0.996000                 ['Francisco Canaro']         0.579
# 12      0.992000                         ['Ka Koula']         0.353
# 13      0.004780                         ['Justrock']         0.643
# 14      0.993000                   ['Takis Nikolaou']         0.453
# 15      0.979000              ['Aggeliki Karagianni']         0.525
# 16      0.972000                 ['Giorgos Katsaros']         0.528
# 17      0.996000                 ['Francisco Canaro']         0.468
# 18      0.750000                 ['Giorgos Katsaros']         0.528
# 19      0.993000                      ['Amalia Vaka']         0.397
# 20      0.023900                ['Ron van der Kraan']         0.744
# 21      0.939000  ["Vasílis Besíris 'Tourkovasílis'"]         0.465
# 22      0.080800                            ['Tr0ma']         0.389
# 23      0.010500                ['Ron van der Kraan']         0.763
# 24      0.000012                  ['Oscar Velazquez']         0.568
# 25      0.250000                           ['Jodoli']         0.521
# 26      0.959000        ['Athanasía Alexandropoúlou']         0.603
# 27      0.984000                      ['Dick Haymes']         0.269
# 28      0.381000                               ['ST']         0.936
# 29      0.984000              ['Manolis Karapiperis']         0.580
# 30      0.944000                      ['Félix Mayol']         0.656
# 31      0.032300                           ['Meetya']         0.697
# 32      0.996000                ['Maurice Chevalier']         0.613
# 33      0.039700                   ['David Daniells']         0.369
# 34      0.021000           ["The Swingin' Bachelors"]         0.559
# 35      0.003970                ['Ron van der Kraan']         0.641
# 36      0.790000           ["The Swingin' Bachelors"]         0.745
# 37      0.007440                ['Ron van der Kraan']         0.737
# 38      0.001740                           ['Meetya']         0.602
# 39      0.310000                             ['biex']         0.639
# 40      0.995000   ['Mamie Smith', 'The Harlem Trio']         0.482
# 41      0.986000                    ['Esther Lekain']         0.641
# 42      0.995000    ['Mamie Smith & Her Jazz Hounds']         0.534
# 43      0.083000               ['Broke God', 'Pcxix']         0.840
# 44      0.000103                 ['Two Charming Men']         0.779
# 45      0.000017                            ['Tr0ma']         0.490
# 46      0.147000           ["The Swingin' Bachelors"]         0.603
# 47      0.367000           ["The Swingin' Bachelors"]         0.716
# 48      0.689000             ['ST', '98', 'Niklas O']         0.690
# 49      0.983000              ['Aryiró Yiannopoúlou']         0.553
#
#     duration_ms  energy  explicit                      id  instrumentalness  \
# 0        168333  0.2240         0  0cS0A1fUEUd1EW3FcF8AEI          0.000522
# 3   True House Music - Xavier Santos & Carlos Gomi...          17
# 4                                           Xuniverxe           2
# 5                         Crazy Blues - 78rpm Version           9
# 6                        Don't You Advertise Your Man           5
# 7                                      Arkansas Blues           0
# 8                        La Chacarera - Remasterizado           0
# 9                        Broken Puppet - Original Mix           0
# 10                                              Oouin           0
# 11                          Desengaño - Remasterizado           0
# 12                                        Ta oula sou           0
# 13                                         Schumacher           0
# 14                                       Mparmpaouzos           0
# 15                                        To katinaki           0
# 16                              Oli mera paizei zaria           0
# 17                        El Africano - Remasterizado           0
# 18                        Vre ti magkas pou eimai ego           0
# 19                              Thelo na se lismoniso           0
# 20                                    On a Ragga Trip           8
# 21                                  Sirtó prevezániko           0
# 22                                            Big Rip           0
# 23                                 Sweet Reggae Music           1
# 24            True House Music - Original Massive Mix           3
# 25                          Taro Yard Slaughter House           0
# 26                                 I photoúla, beráti           0
# 27                              Serenade of the Bells           0
# 28                                   Comme à l'époque           0
# 29                                           Aidiniko           0
# 30                                 Bou Dou Ba Da Bouh           0
# 31                           Day After - Original Mix           0
# 32                                         Oh Maurice           0
# 33                                  Jesus Paid It All           0
# 34                                        Voodoo Doll           0
# 35                               Dancehall Good To Me           1
# 36                                    Penticton Kitty           0
# 37                         Sweat (A La La La La Long)           0
# 38                          Headbanger - Original Mix           0
# 39                                             Kexirr           0
# 40              Kansas City Man Blues - 78rpm Version           4
# 41                              Ca N'vaut Pas L'amour           0
# 42                                           Mean Man           0
# 43                                            #NOHOOK           0
# 44                             Brusque - Original Mix           0
# 45                                Quantum Fluctuation           0
# 46                                            Cloud 9           0
# 47                              Big Jim and the Twins           0
# 48                                                 YP           0
# 49                                   Neráida, tsámiko           0
#
#    release_date  speechiness    tempo  valence  year
# 0          1920       0.0936  149.976   0.6340  1920
# 1    1920-01-05       0.0534   86.889   0.9500  1920
# 2          1920       0.1740   97.600   0.6890  1920
# 3    1920-01-01       0.0425  127.997   0.0422  1920
# 4    1920-10-01       0.0768  122.076   0.2990  1920
# 5          1920       0.0397  103.870   0.4770  1920
# 6          1920       0.0592   85.652   0.4870  1920
# 7          1920       0.0289   78.784   0.3660  1920
# 8    1920-07-08       0.0741  130.060   0.6210  1920
# 9    1920-01-01       0.0446  126.993   0.1190  1920
# 10         1920       0.8450   82.024   0.4140  1920
# 11   1920-07-08       0.0394  131.494   0.7030  1920
# 12   1920-01-01       0.0447  111.268   0.5660  1920
# 13   1920-01-01       0.0566  124.018   0.6390  1920
# 14   1920-01-01       0.0440   67.271   0.8940  1920
# 15   1920-01-01       0.0488  102.578   0.7920  1920
# 16   1920-01-01       0.0421  118.562   0.1460  1920
# 17   1920-07-08       0.0452  136.573   0.7280  1920
# 18   1920-01-01       0.0371  112.817   0.4930  1920
# 19   1920-01-01       0.0498   65.485   0.5150  1920
# 20   1920-01-03       0.0376  140.011   0.5780  1920
# 21   1920-01-01       0.0469   93.128   0.8030  1920
# 22   1920-01-01       0.1090  161.322   0.0710  1920
# 23   1920-01-03       0.1690   88.007   0.4470  1920
# 24   1920-01-01       0.0312  129.987   0.1750  1920
# 25   1920-01-29       0.2680  159.775   0.5670  1920
# 26   1920-01-01       0.0741  118.351   0.9010  1920
# 27         1920       0.0536   79.186   0.1540  1920
# 28         1920       0.4550  133.047   0.2220  1920
# 29   1920-01-01       0.0385  110.562   0.6680  1920
# 30         1920       0.1260  127.325   0.7230  1920
# 31   1920-01-01       0.0609  133.982   0.3210  1920
# 32         1920       0.2250   64.750   0.7690  1920
# 33   1920-04-01       0.0278   68.287   0.3030  1920
# 34   1920-02-29       0.0546  107.912   0.3520  1920
# 35   1920-01-03       0.0571  179.967   0.7520  1920
# 36   1920-02-29       0.0595  120.169   0.6580  1920
# 37   1920-01-03       0.0526  172.025   0.7980  1920
# 38   1920-01-01       0.0439  133.992   0.3960  1920
# 39   1920-06-26       0.0374  127.952   0.7640  1920
# 40         1920       0.0812   77.232   0.4610  1920
# 41         1920       0.1300  116.249   0.6870  1920
# 42         1920       0.0508   70.059   0.6050  1920
# 43   1920-05-16       0.2510  110.105   0.5900  1920
# 44   1920-01-01       0.0482  128.004   0.2260  1920
# 45   1920-01-01       0.0771  158.049   0.2640  1920
# 46   1920-02-29       0.0271   92.010   0.6970  1920
# 47   1920-02-29       0.0451  105.986   0.6350  1920
# 48         1920       0.0726  130.024   0.2650  1920
# 49   1920-01-01       0.0336  110.115   0.5920  1920

# %%
#2.data preprocessing

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25569 entries, 0 to 25568
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   acousticness      25569 non-null  float64
#  1   artists           25569 non-null  object
#  2   danceability      25569 non-null  float64
#  3   duration_ms       25569 non-null  int64
#  4   energy            25569 non-null  float64
#  5   explicit          25569 non-null  int64
#  6   id                25569 non-null  object
#  7   instrumentalness  25569 non-null  float64
#  8   key               25569 non-null  int64
#  9   liveness          25569 non-null  float64
#  10  loudness          25569 non-null  float64
#  11  mode              25569 non-null  int64
#  12  name              25569 non-null  object
#  13  popularity        25569 non-null  int64
#  14  release_date      25569 non-null  object
#  15  speechiness       25569 non-null  float64
#  16  tempo             25569 non-null  float64
#  17  valence           25569 non-null  float64
#  18  year              25569 non-null  int64
# dtypes: float64(9), int64(6), object(4)
# memory usage: 3.7+ MB

# %%
data.isnull().sum()
# Out:
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# valence             0
# year                0
# dtype: int64

# %%
df = data.drop(columns=['id', 'name', 'artists', 'release_date', 'year'])
df.corr()
# Out:
#                   acousticness  danceability  duration_ms    energy  explicit  \
# acousticness          1.000000     -0.205249    -0.133389 -0.745771 -0.260715
# danceability         -0.205249      1.000000    -0.158758  0.157935  0.216589
# duration_ms          -0.133389     -0.158758     1.000000  0.099098 -0.039290
# energy               -0.745771      0.157935     0.099098  1.000000  0.103260
# explicit             -0.260715      0.216589    -0.039290  0.103260  1.000000
# instrumentalness      0.336283     -0.223332     0.048093 -0.253737 -0.145097
# key                  -0.010677      0.018772     0.000168  0.001449  0.010501
# liveness             -0.005469     -0.104384     0.044232  0.088999  0.042714
# loudness             -0.504102      0.194854     0.058019  0.769314  0.085804
# mode                  0.049648     -0.041901    -0.038588 -0.021555 -0.064362
# popularity           -0.573705      0.118785     0.125491  0.494302  0.119289
# speechiness          -0.071965      0.269767    -0.109479 -0.139897  0.364696
# tempo                -0.173354      0.018540    -0.020062  0.247891  0.000279
# valence              -0.132634      0.556767    -0.208963  0.327431 -0.024775
#
#                   instrumentalness       key  liveness  loudness      mode  \
# acousticness              0.336283 -0.010677 -0.005469 -0.504102  0.049648
# danceability             -0.223332  0.018772 -0.104384  0.194854 -0.041901
# duration_ms               0.048093  0.000168  0.044232  0.058019 -0.038588
# energy                   -0.253737  0.001449  0.088999  0.769314 -0.021555
# explicit                 -0.145097  0.010501  0.042714  0.085804 -0.064362
# instrumentalness          1.000000  0.000081 -0.042581 -0.353350 -0.035960
# key                       0.000081  1.000000  0.005220  0.003872 -0.105747
# liveness                 -0.042581  0.005220  1.000000  0.044031  0.001972
# loudness                 -0.353350  0.003872  0.044031  1.000000  0.011613
# mode                     -0.035960 -0.105747  0.001972  0.011613  1.000000
# popularity               -0.362931 -0.001496 -0.111029  0.437608  0.012849
# speechiness              -0.137896  0.010072  0.109205 -0.269641 -0.064123
# tempo                    -0.076834 -0.006933 -0.006273  0.209560  0.023969
# valence                  -0.177100  0.015485  0.002454  0.296380  0.028523
#
#                   popularity  speechiness     tempo   valence
# acousticness       -0.573705    -0.071965 -0.173354 -0.132634
# danceability        0.118785     0.269767  0.018540  0.556767
# duration_ms         0.125491    -0.109479 -0.020062 -0.208963
# energy              0.494302    -0.139897  0.247891  0.327431
# explicit            0.119289     0.364696  0.000279 -0.024775
# instrumentalness   -0.362931    -0.137896 -0.076834 -0.177100
# key                -0.001496     0.010072 -0.006933  0.015485
# liveness           -0.111029     0.109205 -0.006273  0.002454
# loudness            0.437608    -0.269641  0.209560  0.296380
# mode                0.012849    -0.064123  0.023969  0.028523
# popularity          1.000000    -0.252441  0.114819  0.048046
# speechiness        -0.252441     1.000000 -0.044547  0.061701
# tempo               0.114819    -0.044547  1.000000  0.203653
# valence             0.048046     0.061701  0.203653  1.000000

# %%
##Data transformation
from sklearn.preprocessing import MinMaxScaler
datatypes = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
normalization = data.select_dtypes(include=datatypes)
for col in normalization.columns:
    MinMaxScaler(col)

# %%
#importing K- means from sklearn
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=20)
features = kmeans.fit_predict(normalization)
data['features'] = features
MinMaxScaler(data['features'])
# Out:
# MinMaxScaler(feature_range=0        19
# 1        19
# 2        19
# 3        12
# 4        19
#          ..
# 25564     0
# 25565    15
# 25566    14
# 25567    19
# 25568    19
# Name: features, Length: 25569, dtype: int32)

# %%
class Music_Recommendation():
    def __init__(self, dataset):
        self.dataset = dataset
    def recommend(self, songs, amount=1):
        distance = []
        song = self.dataset[(self.dataset.name.str.lower() == songs.lower())].head(1).values[0]
        rec = self.dataset[self.dataset.name.str.lower() != songs.lower()]
        for songs in tqdm(rec.values):
            d = 0
            for col in np.arange(len(rec.columns)):
                if not col in [1, 6, 12, 14, 18]:
                    d = d + np.absolute(float(song[col]) - float(songs[col]))
            distance.append(d)
        rec['distance'] = distance
        rec = rec.sort_values('distance')
        columns = ['artists', 'name']
        return rec[columns][:amount]

recommendations = Music_Recommendation(data)

# %%
recommendations.recommend("Lovers Rock", 5)
# Out:
# 100%|██████████| 25568/25568 [00:02<00:00, 8686.39it/s]
# C:\Users\PRASAD~1\AppData\Local\Temp/ipykernel_18584/2754423189.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#                             artists                       name
# 16385                    ['O-Zone']          Dragostea Din Tei
# 11168  ['Bob Marley & The Wailers']         Positive Vibration
# 7119            ['Ella Fitzgerald']  Ev'ry Time We Say Goodbye
# 16590               ['Linkin Park']         Somewhere I Belong
# 12287      ['The Psychedelic Furs']                Love My Way

# %%
recommendations.recommend("Lovers Rock", 10)
# Out:
# 100%|██████████| 25568/25568 [00:02<00:00, 8711.27it/s]
# C:\Users\PRASAD~1\AppData\Local\Temp/ipykernel_18584/289738197.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#                             artists                                   name
# 16385                    ['O-Zone']                      Dragostea Din Tei
# 11168  ['Bob Marley & The Wailers']                     Positive Vibration
# 7119            ['Ella Fitzgerald']              Ev'ry Time We Say Goodbye
# 16590               ['Linkin Park']                     Somewhere I Belong
# 12287      ['The Psychedelic Furs']                            Love My Way
# 15532                ['Tracy Byrd']  I'm From The Country - Single Version
# 11921             ['Robbie Dupree']                Steal Away - Remastered
# 1413             ['Jimmie Rodgers']                          Memphis Yodel
# 6940              ['Frank Sinatra']    This Love Of Mine - 1998 Remastered
# 14588      ['Los Tigres Del Norte']                        Pacas De A Kilo

# %%
recommendations.recommend("Lovers Rock", 15)
# Out:
# 100%|██████████| 25568/25568 [00:03<00:00, 8444.12it/s]
# C:\Users\PRASAD~1\AppData\Local\Temp/ipykernel_18584/289738197.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   rec['distance'] = distance
#                             artists                                   name
# 16385                    ['O-Zone']                      Dragostea Din Tei
# 11168  ['Bob Marley & The Wailers']                     Positive Vibration
# 7119            ['Ella Fitzgerald']              Ev'ry Time We Say Goodbye
# 16590               ['Linkin Park']                     Somewhere I Belong
# 12287      ['The Psychedelic Furs']                            Love My Way
# 15532                ['Tracy Byrd']  I'm From The Country - Single Version
# 11921             ['Robbie Dupree']                Steal Away - Remastered
# 1413             ['Jimmie Rodgers']                          Memphis Yodel
# 6940              ['Frank Sinatra']    This Love Of Mine - 1998 Remastered
# 14588      ['Los Tigres Del Norte']                        Pacas De A Kilo
# 11195     ['Sanford Townsend Band']              Smoke from a Distant Fire
# 24257             ['Alberto Gomez']                         Noche de Abril
# 9484                ['The Zombies']      Time of the Season - Mono Version
# 16498                       ['Jet']               Are You Gonna Be My Girl
# 9352                ['The Zombies']                     Time of the Season
